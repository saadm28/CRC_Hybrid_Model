# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, LeakyReLU, Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import legacy, Adam, RMSprop
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report

# %%
# Verify TensorFlow can access the GPU
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Check TensorFlow version
print(tf.__version__)
# Out:
# Num GPUs Available:  1
# 2.17.0

# %%
# Load in images

# Set the path to your dataset directory
dataset_path = 'Data'

# Create an ImageDataGenerator object
train_datagen = ImageDataGenerator(dtype = 'float32', preprocessing_function=preprocess_input, validation_split=0.2)

# Set the batch size
batch_size = 32

# Load training data from directory
train_data = train_datagen.flow_from_directory(
    directory=f'{dataset_path}/EXTRA/TRAINING_DATA',
    target_size=(224, 224),  # Resize all images to 224x224
    batch_size=batch_size,
    class_mode='binary',  # Use 'binary' for binary classification problems
    shuffle=True,
    seed=42,  # For reproducibility
    subset='training',  # Specify this part is for training
)

# Load validation data from the same directory
val_data = train_datagen.flow_from_directory(
    directory=f'{dataset_path}/EXTRA/TRAINING_DATA',
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False, # optional for validation
    # seed=42,
    subset='validation',  # Specify this part is for validation
)
# Out:
# Found 74728 images belonging to 2 classes.
# Found 18681 images belonging to 2 classes.

# %%
# check if any filenames same in both training and validation data
train_files = set(train_data.filenames)
val_files = set(val_data.filenames)
common_files = train_files.intersection(val_files)
print(f'Number of common files in training and validation data: {len(common_files)}')
# Out:
# Number of common files in training and validation data: 0

# %%
# check images data type
print(train_data[0][0].dtype)
# Out:
# float32

# %%
# print class names for each dataset
print('Training Data Classes:', train_data.class_indices)
print('Validation Data Classes:', val_data.class_indices)
# print('Testing Data Classes:', test_data.class_indices)
# Out:
# Training Data Classes: {'MSI': 0, 'MSS': 1}
# Validation Data Classes: {'MSI': 0, 'MSS': 1}

# %%
# Print class distribution for each dataset

# Training Data
train_class_distribution = pd.Series(train_data.classes).value_counts()
print('Training Data Class Distribution:')
print(train_class_distribution)

# Validation Data
val_class_distribution = pd.Series(val_data.classes).value_counts()
print('Validation Data Class Distribution:')
print(val_class_distribution)
# Out:
# Training Data Class Distribution:
# 0    37364
# 1    37364
# dtype: int64
# Validation Data Class Distribution:
# 1    9341
# 0    9340
# dtype: int64

# %% [markdown]
# ## VGG-19 Model

# %%
from tensorflow.keras.applications import VGG19

# Load the VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
base_model.trainable = False

# Model Layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(x)  # L2 regularization
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

# Creating the full model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Model summary to inspect the architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,600,321 (82.40 MB)
#  Trainable params: 1,575,937 (6.01 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# train resunet model with callbacks

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=1)

history = model.fit(
    train_data,
    epochs=100,
    validation_data=val_data,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 2024-08-01 03:13:01.859017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 840s 358ms/step - accuracy: 0.5988 - loss: 4.2683 - val_accuracy: 0.6955 - val_loss: 1.2273 - learning_rate: 1.0000e-04
# Epoch 2/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 866s 371ms/step - accuracy: 0.6474 - loss: 1.1017 - val_accuracy: 0.6961 - val_loss: 0.7890 - learning_rate: 1.0000e-04
# Epoch 3/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 894s 382ms/step - accuracy: 0.6572 - loss: 0.7816 - val_accuracy: 0.6983 - val_loss: 0.6773 - learning_rate: 1.0000e-04
# Epoch 4/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 963s 412ms/step - accuracy: 0.6689 - loss: 0.6878 - val_accuracy: 0.7101 - val_loss: 0.6295 - learning_rate: 1.0000e-04
# Epoch 5/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 844s 361ms/step - accuracy: 0.6763 - loss: 0.6510 - val_accuracy: 0.7223 - val_loss: 0.5962 - learning_rate: 1.0000e-04
# Epoch 6/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 872s 373ms/step - accuracy: 0.6846 - loss: 0.6276 - val_accuracy: 0.7237 - val_loss: 0.5966 - learning_rate: 1.0000e-04
# Epoch 7/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 944s 404ms/step - accuracy: 0.6939 - loss: 0.6106 - val_accuracy: 0.7338 - val_loss: 0.5693 - learning_rate: 1.0000e-04
# Epoch 8/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 849s 363ms/step - accuracy: 0.7003 - loss: 0.5991 - val_accuracy: 0.7383 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 9/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 822s 352ms/step - accuracy: 0.7035 - loss: 0.5925 - val_accuracy: 0.7396 - val_loss: 0.5534 - learning_rate: 1.0000e-04
# Epoch 10/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 821s 351ms/step - accuracy: 0.7080 - loss: 0.5859 - val_accuracy: 0.7332 - val_loss: 0.5585 - learning_rate: 1.0000e-04
# Epoch 11/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 821s 351ms/step - accuracy: 0.7121 - loss: 0.5803 - val_accuracy: 0.7360 - val_loss: 0.5513 - learning_rate: 1.0000e-04
# Epoch 12/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 821s 351ms/step - accuracy: 0.7207 - loss: 0.5713 - val_accuracy: 0.7541 - val_loss: 0.5376 - learning_rate: 1.0000e-04
# Epoch 13/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7154 - loss: 0.5706 - val_accuracy: 0.7459 - val_loss: 0.5371 - learning_rate: 1.0000e-04
# Epoch 14/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 822s 351ms/step - accuracy: 0.7206 - loss: 0.5660 - val_accuracy: 0.7461 - val_loss: 0.5413 - learning_rate: 1.0000e-04
# Epoch 15/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 822s 351ms/step - accuracy: 0.7255 - loss: 0.5627 - val_accuracy: 0.7600 - val_loss: 0.5233 - learning_rate: 1.0000e-04
# Epoch 16/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 822s 352ms/step - accuracy: 0.7272 - loss: 0.5621 - val_accuracy: 0.7570 - val_loss: 0.5207 - learning_rate: 1.0000e-04
# Epoch 17/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7307 - loss: 0.5571 - val_accuracy: 0.7502 - val_loss: 0.5299 - learning_rate: 1.0000e-04
# Epoch 18/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7324 - loss: 0.5549 - val_accuracy: 0.7640 - val_loss: 0.5189 - learning_rate: 1.0000e-04
# Epoch 19/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7336 - loss: 0.5518 - val_accuracy: 0.7631 - val_loss: 0.5164 - learning_rate: 1.0000e-04
# Epoch 20/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7333 - loss: 0.5522 - val_accuracy: 0.7683 - val_loss: 0.5196 - learning_rate: 1.0000e-04
# Epoch 21/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7358 - loss: 0.5486 - val_accuracy: 0.7705 - val_loss: 0.5140 - learning_rate: 1.0000e-04
# Epoch 22/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7376 - loss: 0.5462 - val_accuracy: 0.7470 - val_loss: 0.5332 - learning_rate: 1.0000e-04
# Epoch 23/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7401 - loss: 0.5458 - val_accuracy: 0.7633 - val_loss: 0.5146 - learning_rate: 1.0000e-04
# Epoch 24/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7391 - loss: 0.5448 - val_accuracy: 0.7695 - val_loss: 0.5058 - learning_rate: 1.0000e-04
# Epoch 25/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7400 - loss: 0.5433 - val_accuracy: 0.7714 - val_loss: 0.5069 - learning_rate: 1.0000e-04
# Epoch 26/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7434 - loss: 0.5413 - val_accuracy: 0.7700 - val_loss: 0.5075 - learning_rate: 1.0000e-04
# Epoch 27/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7411 - loss: 0.5429 - val_accuracy: 0.7669 - val_loss: 0.5129 - learning_rate: 1.0000e-04
# Epoch 28/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7437 - loss: 0.5409 - val_accuracy: 0.7639 - val_loss: 0.5103 - learning_rate: 1.0000e-04
# Epoch 29/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.7428 - loss: 0.5375
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7428 - loss: 0.5375 - val_accuracy: 0.7556 - val_loss: 0.5164 - learning_rate: 1.0000e-04
# Epoch 30/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7565 - loss: 0.5210 - val_accuracy: 0.7813 - val_loss: 0.4856 - learning_rate: 2.0000e-05
# Epoch 31/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7581 - loss: 0.5177 - val_accuracy: 0.7812 - val_loss: 0.4840 - learning_rate: 2.0000e-05
# Epoch 32/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7606 - loss: 0.5097 - val_accuracy: 0.7871 - val_loss: 0.4775 - learning_rate: 2.0000e-05
# Epoch 33/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7615 - loss: 0.5103 - val_accuracy: 0.7831 - val_loss: 0.4789 - learning_rate: 2.0000e-05
# Epoch 34/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7617 - loss: 0.5079 - val_accuracy: 0.7833 - val_loss: 0.4795 - learning_rate: 2.0000e-05
# Epoch 35/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7658 - loss: 0.5037 - val_accuracy: 0.7850 - val_loss: 0.4773 - learning_rate: 2.0000e-05
# Epoch 36/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7684 - loss: 0.5002 - val_accuracy: 0.7901 - val_loss: 0.4730 - learning_rate: 2.0000e-05
# Epoch 37/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7621 - loss: 0.5056 - val_accuracy: 0.7878 - val_loss: 0.4728 - learning_rate: 2.0000e-05
# Epoch 38/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7693 - loss: 0.4983 - val_accuracy: 0.7893 - val_loss: 0.4708 - learning_rate: 2.0000e-05
# Epoch 39/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7708 - loss: 0.4959 - val_accuracy: 0.7899 - val_loss: 0.4691 - learning_rate: 2.0000e-05
# Epoch 40/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7700 - loss: 0.4977 - val_accuracy: 0.7849 - val_loss: 0.4726 - learning_rate: 2.0000e-05
# Epoch 41/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 823s 352ms/step - accuracy: 0.7692 - loss: 0.4966 - val_accuracy: 0.7868 - val_loss: 0.4709 - learning_rate: 2.0000e-05
# Epoch 42/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7710 - loss: 0.4911 - val_accuracy: 0.7902 - val_loss: 0.4693 - learning_rate: 2.0000e-05
# Epoch 43/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7740 - loss: 0.4893 - val_accuracy: 0.7882 - val_loss: 0.4725 - learning_rate: 2.0000e-05
# Epoch 44/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.7707 - loss: 0.4926
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-05.
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7707 - loss: 0.4926 - val_accuracy: 0.7890 - val_loss: 0.4691 - learning_rate: 2.0000e-05
# Epoch 45/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 352ms/step - accuracy: 0.7764 - loss: 0.4871 - val_accuracy: 0.7944 - val_loss: 0.4614 - learning_rate: 1.0000e-05
# Epoch 46/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7758 - loss: 0.4863 - val_accuracy: 0.7935 - val_loss: 0.4612 - learning_rate: 1.0000e-05
# Epoch 47/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7760 - loss: 0.4864 - val_accuracy: 0.7931 - val_loss: 0.4639 - learning_rate: 1.0000e-05
# Epoch 48/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7760 - loss: 0.4859 - val_accuracy: 0.7950 - val_loss: 0.4620 - learning_rate: 1.0000e-05
# Epoch 49/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7761 - loss: 0.4842 - val_accuracy: 0.7935 - val_loss: 0.4607 - learning_rate: 1.0000e-05
# Epoch 50/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 836s 358ms/step - accuracy: 0.7766 - loss: 0.4834 - val_accuracy: 0.7924 - val_loss: 0.4617 - learning_rate: 1.0000e-05
# Epoch 51/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 866s 370ms/step - accuracy: 0.7788 - loss: 0.4831 - val_accuracy: 0.7927 - val_loss: 0.4613 - learning_rate: 1.0000e-05
# Epoch 52/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 883s 377ms/step - accuracy: 0.7771 - loss: 0.4844 - val_accuracy: 0.7935 - val_loss: 0.4607 - learning_rate: 1.0000e-05
# Epoch 53/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 899s 385ms/step - accuracy: 0.7766 - loss: 0.4850 - val_accuracy: 0.7944 - val_loss: 0.4615 - learning_rate: 1.0000e-05
# Epoch 54/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 840s 359ms/step - accuracy: 0.7794 - loss: 0.4805 - val_accuracy: 0.7944 - val_loss: 0.4605 - learning_rate: 1.0000e-05
# Epoch 55/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 824s 353ms/step - accuracy: 0.7755 - loss: 0.4830 - val_accuracy: 0.7926 - val_loss: 0.4600 - learning_rate: 1.0000e-05
# Epoch 56/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 831s 356ms/step - accuracy: 0.7782 - loss: 0.4805 - val_accuracy: 0.7959 - val_loss: 0.4584 - learning_rate: 1.0000e-05
# Epoch 57/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 883s 378ms/step - accuracy: 0.7770 - loss: 0.4798 - val_accuracy: 0.7944 - val_loss: 0.4591 - learning_rate: 1.0000e-05
# Epoch 58/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 918s 393ms/step - accuracy: 0.7808 - loss: 0.4813 - val_accuracy: 0.7928 - val_loss: 0.4589 - learning_rate: 1.0000e-05
# Epoch 59/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 910s 389ms/step - accuracy: 0.7776 - loss: 0.4805 - val_accuracy: 0.7934 - val_loss: 0.4577 - learning_rate: 1.0000e-05
# Epoch 60/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 946s 405ms/step - accuracy: 0.7803 - loss: 0.4770 - val_accuracy: 0.7936 - val_loss: 0.4570 - learning_rate: 1.0000e-05
# Epoch 61/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 963s 412ms/step - accuracy: 0.7795 - loss: 0.4782 - val_accuracy: 0.7939 - val_loss: 0.4589 - learning_rate: 1.0000e-05
# Epoch 62/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 956s 409ms/step - accuracy: 0.7769 - loss: 0.4827 - val_accuracy: 0.7954 - val_loss: 0.4567 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 994s 425ms/step - accuracy: 0.7843 - loss: 0.4724 - val_accuracy: 0.7958 - val_loss: 0.4570 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 847s 362ms/step - accuracy: 0.7764 - loss: 0.4802 - val_accuracy: 0.7935 - val_loss: 0.4579 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7806 - loss: 0.4735 - val_accuracy: 0.7942 - val_loss: 0.4576 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7832 - loss: 0.4763 - val_accuracy: 0.7943 - val_loss: 0.4576 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7799 - loss: 0.4769 - val_accuracy: 0.7962 - val_loss: 0.4578 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7826 - loss: 0.4749 - val_accuracy: 0.7977 - val_loss: 0.4546 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7825 - loss: 0.4732 - val_accuracy: 0.7954 - val_loss: 0.4565 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7845 - loss: 0.4740 - val_accuracy: 0.7964 - val_loss: 0.4552 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7858 - loss: 0.4703 - val_accuracy: 0.7985 - val_loss: 0.4542 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 827s 354ms/step - accuracy: 0.7838 - loss: 0.4723 - val_accuracy: 0.7959 - val_loss: 0.4562 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7831 - loss: 0.4712 - val_accuracy: 0.7945 - val_loss: 0.4568 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 825s 353ms/step - accuracy: 0.7814 - loss: 0.4713 - val_accuracy: 0.7978 - val_loss: 0.4535 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7839 - loss: 0.4732 - val_accuracy: 0.7951 - val_loss: 0.4567 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 831s 355ms/step - accuracy: 0.7812 - loss: 0.4723 - val_accuracy: 0.7980 - val_loss: 0.4542 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 837s 358ms/step - accuracy: 0.7816 - loss: 0.4737 - val_accuracy: 0.7962 - val_loss: 0.4554 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 826s 353ms/step - accuracy: 0.7854 - loss: 0.4679 - val_accuracy: 0.7969 - val_loss: 0.4542 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 831s 355ms/step - accuracy: 0.7833 - loss: 0.4692 - val_accuracy: 0.7952 - val_loss: 0.4549 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 869s 372ms/step - accuracy: 0.7850 - loss: 0.4688 - val_accuracy: 0.7967 - val_loss: 0.4521 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 870s 372ms/step - accuracy: 0.7852 - loss: 0.4697 - val_accuracy: 0.8005 - val_loss: 0.4521 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 873s 374ms/step - accuracy: 0.7865 - loss: 0.4675 - val_accuracy: 0.7972 - val_loss: 0.4533 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 837s 358ms/step - accuracy: 0.7882 - loss: 0.4635 - val_accuracy: 0.7972 - val_loss: 0.4545 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 849s 363ms/step - accuracy: 0.7854 - loss: 0.4685 - val_accuracy: 0.7951 - val_loss: 0.4532 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 882s 377ms/step - accuracy: 0.7883 - loss: 0.4657 - val_accuracy: 0.7940 - val_loss: 0.4563 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 872s 373ms/step - accuracy: 0.7857 - loss: 0.4686 - val_accuracy: 0.7962 - val_loss: 0.4540 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 871s 373ms/step - accuracy: 0.7852 - loss: 0.4663 - val_accuracy: 0.7957 - val_loss: 0.4536 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 884s 378ms/step - accuracy: 0.7912 - loss: 0.4636 - val_accuracy: 0.8000 - val_loss: 0.4509 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 891s 381ms/step - accuracy: 0.7879 - loss: 0.4616 - val_accuracy: 0.7959 - val_loss: 0.4544 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 886s 379ms/step - accuracy: 0.7878 - loss: 0.4649 - val_accuracy: 0.7965 - val_loss: 0.4531 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 928s 397ms/step - accuracy: 0.7880 - loss: 0.4630 - val_accuracy: 0.7964 - val_loss: 0.4515 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 904s 387ms/step - accuracy: 0.7895 - loss: 0.4620 - val_accuracy: 0.7976 - val_loss: 0.4508 - learning_rate: 1.0000e-05
# Epoch 93/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 921s 394ms/step - accuracy: 0.7900 - loss: 0.4634 - val_accuracy: 0.7984 - val_loss: 0.4505 - learning_rate: 1.0000e-05
# Epoch 94/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 942s 403ms/step - accuracy: 0.7896 - loss: 0.4638 - val_accuracy: 0.7992 - val_loss: 0.4505 - learning_rate: 1.0000e-05
# Epoch 95/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 1005s 430ms/step - accuracy: 0.7872 - loss: 0.4662 - val_accuracy: 0.7984 - val_loss: 0.4513 - learning_rate: 1.0000e-05
# Epoch 96/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 956s 409ms/step - accuracy: 0.7913 - loss: 0.4605 - val_accuracy: 0.7987 - val_loss: 0.4481 - learning_rate: 1.0000e-05
# Epoch 97/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 962s 412ms/step - accuracy: 0.7888 - loss: 0.4639 - val_accuracy: 0.7994 - val_loss: 0.4491 - learning_rate: 1.0000e-05
# Epoch 98/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 945s 404ms/step - accuracy: 0.7885 - loss: 0.4616 - val_accuracy: 0.8007 - val_loss: 0.4484 - learning_rate: 1.0000e-05
# Epoch 99/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 917s 392ms/step - accuracy: 0.7891 - loss: 0.4622 - val_accuracy: 0.7975 - val_loss: 0.4508 - learning_rate: 1.0000e-05
# Epoch 100/100
# 2336/2336 ━━━━━━━━━━━━━━━━━━━━ 916s 392ms/step - accuracy: 0.7863 - loss: 0.4621 - val_accuracy: 0.7965 - val_loss: 0.4514 - learning_rate: 1.0000e-05

# %%
# evaluate the model
test_loss, test_accuracy = model.evaluate(val_data)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 179s 306ms/step - accuracy: 0.7997 - loss: 0.4372
# Test Accuracy: 0.798725962638855

# %%
# plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# get model evaluation metrics: F1 score, precision, recall

# make predictions on the test set
predictions = model.predict(val_data)
# convert predictions to binary
binary_predictions = np.where(predictions > 0.5, 1, 0)

# get classification report
report = classification_report(val_data.classes, binary_predictions)
print(report)
# Out:
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 187s 320ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      9340
#            1       0.80      0.80      0.80      9341
#
#     accuracy                           0.80     18681
#    macro avg       0.80      0.80      0.80     18681
# weighted avg       0.80      0.80      0.80     18681

# %%
# import seaborn and confusion matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix

# get confusion matrix
cm = confusion_matrix(val_data.classes, binary_predictions)

# plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=val_data.class_indices, yticklabels=val_data.class_indices)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# sensitivity and specificity
# sensitivity = TP / (TP + FN)
# specificity = TN / (TN + FP)

# get true positive, true negative, false positive, false negative
TP = cm[1][1]
TN = cm[0][0]
FP = cm[0][1]
FN = cm[1][0]

# calculate sensitivity and specificity
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

print(f'Sensitivity: {sensitivity}')
print(f'Specificity: {specificity}')
# Out:
# Sensitivity: 0.800877850337223
# Specificity: 0.7965738758029979

# %%
# get AUC-ROC score
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(val_data.classes, binary_predictions)
print(f'AUC-ROC Score: {roc_auc}')
# Out:
# AUC-ROC Score: 0.7987258630701105

# %%
# save model as resunet_model in tf format

# model.save('resnet_model_final', save_format='tf')

# %% [markdown]
# ## Additional Results

# %%
# plot ROC curve
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(val_data.classes, binary_predictions)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
# create function to calculate Matthew’s correlation coefficient

def calculate_mcc(y_true, y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    tp = conf_matrix[0, 0]
    tn = conf_matrix[1, 1]
    fp = conf_matrix[0, 1]
    fn = conf_matrix[1, 0]
    mcc = (tp * tn - fp * fn) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    return mcc

# %%
# use function to calculate MCC
mcc = calculate_mcc(val_data.classes, binary_predictions)
print(f'MCC: {mcc}')
# Out:
# MCC: 0.5974573415641345
